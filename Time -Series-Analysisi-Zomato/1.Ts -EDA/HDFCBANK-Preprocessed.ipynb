# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
HDFCBANK_stock_data_with_date

# %%
dataset=pd.read_csv("HDFCBANK_stock_data_with_date.csv",parse_dates=['Date'], index_col='Date')
dataset
# Out:
#                      Adj Close               Close               High  \
# Date
# NaT                HDFCBANK.NS         HDFCBANK.NS        HDFCBANK.NS
# 2021-07-01    1433.42529296875             1486.75             1502.0
# 2021-07-02  1427.3031005859375  1480.4000244140625            1489.25
# 2021-07-05   1441.813232421875   1495.449951171875             1504.5
# 2021-07-06  1479.6553955078125   1534.699951171875             1540.0
# ...                        ...                 ...                ...
# 2022-01-19       1463.98828125   1518.449951171875            1539.75
# 2022-01-20   1454.877197265625              1509.0             1528.5
# 2022-01-21      1467.025390625  1521.5999755859375  1529.800048828125
# 2022-01-24  1433.3289794921875  1486.6500244140625            1521.25
# 2022-01-25     1434.6787109375   1488.050048828125             1495.0
#
#                            Low                Open       Volume
# Date
# ...

# %%
dataset = dataset.drop(['Adj Close', 'Volume'], axis=1)

# %%
dataset
# Out:
#                          Close               High                 Low  \
# Date
# NaT                HDFCBANK.NS        HDFCBANK.NS         HDFCBANK.NS
# 2021-07-01             1486.75             1502.0              1483.0
# 2021-07-02  1480.4000244140625            1489.25              1477.0
# 2021-07-05   1495.449951171875             1504.5   1484.550048828125
# 2021-07-06   1534.699951171875             1540.0              1496.0
# ...                        ...                ...                 ...
# 2022-01-19   1518.449951171875            1539.75  1513.3499755859375
# 2022-01-20              1509.0             1528.5  1500.0999755859375
# 2022-01-21  1521.5999755859375  1529.800048828125  1485.5999755859375
# 2022-01-24  1486.6500244140625            1521.25   1467.550048828125
# 2022-01-25   1488.050048828125             1495.0              1444.0
#
#                           Open
# Date
# NaT                HDFCBANK.NS
# 2021-07-01              1502.0
# ...

# %%
dataset = dataset[~dataset.isin(['NaT', 'HDFCBANK.NS']).any(axis=1)]

# %%
dataset
# Out:
#                          Close                High                 Low  \
# Date
# 2021-07-01             1486.75              1502.0              1483.0
# 2021-07-02  1480.4000244140625             1489.25              1477.0
# 2021-07-05   1495.449951171875              1504.5   1484.550048828125
# 2021-07-06   1534.699951171875              1540.0              1496.0
# 2021-07-07              1539.5  1545.3499755859375   1527.699951171875
# ...                        ...                 ...                 ...
# 2022-01-19   1518.449951171875             1539.75  1513.3499755859375
# 2022-01-20              1509.0              1528.5  1500.0999755859375
# 2022-01-21  1521.5999755859375   1529.800048828125  1485.5999755859375
# 2022-01-24  1486.6500244140625             1521.25   1467.550048828125
# 2022-01-25   1488.050048828125              1495.0              1444.0
#
#                           Open
# Date
# 2021-07-01              1502.0
# 2021-07-02              1485.0
# ...

# %%
dataset.to_csv('

# %%
dataset.to_csv('HDFCBANK_stock_data.csv', index=True)
