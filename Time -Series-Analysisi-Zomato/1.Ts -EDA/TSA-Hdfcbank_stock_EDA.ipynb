# %%
import pandas as pd

# %%
#!pip install yfinance

# %%
#!pip install nsepy

# %%
from Descriptive import Descriptive

# %%
obj=Descriptive()

# %%
import datetime as dt
import yfinance as yf
import pandas as pd

# Define the time period and stock symbol
start = dt.datetime(2021, 7, 1)
end = dt.datetime(2022, 1, 27)
symbol = 'HDFCBANK.NS'

# Download stock data
stk_data = yf.download(symbol, start=start, end=end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
stk_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 143 entries, 2021-07-01 to 2022-01-25
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   (Adj Close, HDFCBANK.NS)  143 non-null    float64
#  1   (Close, HDFCBANK.NS)      143 non-null    float64
#  2   (High, HDFCBANK.NS)       143 non-null    float64
#  3   (Low, HDFCBANK.NS)        143 non-null    float64
#  4   (Open, HDFCBANK.NS)       143 non-null    float64
#  5   (Volume, HDFCBANK.NS)     143 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 7.8 KB

# %%
#import yfinance as yf

# Fetch historical data for HDFC Bank (NSE)
#data_nse = yf.download('HDFCBANK.NS', start="2020-01-01", end="2023-12-31")

# Display the first few rows
#print(data_nse.head())

# %%
stk_data
# Out:
# Price         Adj Close        Close         High          Low         Open  \
# Ticker      HDFCBANK.NS  HDFCBANK.NS  HDFCBANK.NS  HDFCBANK.NS  HDFCBANK.NS
# Date
# 2021-07-01  1433.425293  1486.750000  1502.000000  1483.000000  1502.000000
# 2021-07-02  1427.303101  1480.400024  1489.250000  1477.000000  1485.000000
# 2021-07-05  1441.813232  1495.449951  1504.500000  1484.550049  1489.949951
# 2021-07-06  1479.655518  1534.699951  1540.000000  1496.000000  1497.000000
# 2021-07-07  1484.283325  1539.500000  1545.349976  1527.699951  1534.000000
# ...                 ...          ...          ...          ...          ...
# 2022-01-19  1463.988281  1518.449951  1539.750000  1513.349976  1534.000000
# 2022-01-20  1454.877319  1509.000000  1528.500000  1500.099976  1528.449951
# 2022-01-21  1467.025391  1521.599976  1529.800049  1485.599976  1500.000000
# 2022-01-24  1433.328857  1486.650024  1521.250000  1467.550049  1509.949951
# 2022-01-25  1434.678711  1488.050049  1495.000000  1444.000000  1458.650024
#
# Price           Volume
# Ticker     HDFCBANK.NS
# Date
# 2021-07-01     8455721
# 2021-07-02     7413518
# 2021-07-05     3686941
# 2021-07-06     8834516
# 2021-07-07     4814595
# ...                ...
# 2022-01-19     7158813
# 2022-01-20     7598923
# 2022-01-21     5768847
# 2022-01-24     5934254
# 2022-01-25     6797124
#
# [143 rows x 6 columns]

# %%
stk_data = stk_data[["Open", "High", "Low", "Close"]]

# %%
stk_data
# Out:
# Price              Open         High          Low        Close
# Ticker      HDFCBANK.NS  HDFCBANK.NS  HDFCBANK.NS  HDFCBANK.NS
# Date
# 2021-07-01  1502.000000  1502.000000  1483.000000  1486.750000
# 2021-07-02  1485.000000  1489.250000  1477.000000  1480.400024
# 2021-07-05  1489.949951  1504.500000  1484.550049  1495.449951
# 2021-07-06  1497.000000  1540.000000  1496.000000  1534.699951
# 2021-07-07  1534.000000  1545.349976  1527.699951  1539.500000
# ...                 ...          ...          ...          ...
# 2022-01-19  1534.000000  1539.750000  1513.349976  1518.449951
# 2022-01-20  1528.449951  1528.500000  1500.099976  1509.000000
# 2022-01-21  1500.000000  1529.800049  1485.599976  1521.599976
# 2022-01-24  1509.949951  1521.250000  1467.550049  1486.650024
# 2022-01-25  1458.650024  1495.000000  1444.000000  1488.050049
#
# [143 rows x 4 columns]

# %%
# Adjust to your column names
new_headers = ['Open','High','Low','Close'] 
stk_data.columns = new_headers

# %%
stk_data
# Out:
#                    Open         High          Low        Close
# Date
# 2021-07-01  1502.000000  1502.000000  1483.000000  1486.750000
# 2021-07-02  1485.000000  1489.250000  1477.000000  1480.400024
# 2021-07-05  1489.949951  1504.500000  1484.550049  1495.449951
# 2021-07-06  1497.000000  1540.000000  1496.000000  1534.699951
# 2021-07-07  1534.000000  1545.349976  1527.699951  1539.500000
# ...                 ...          ...          ...          ...
# 2022-01-19  1534.000000  1539.750000  1513.349976  1518.449951
# 2022-01-20  1528.449951  1528.500000  1500.099976  1509.000000
# 2022-01-21  1500.000000  1529.800049  1485.599976  1521.599976
# 2022-01-24  1509.949951  1521.250000  1467.550049  1486.650024
# 2022-01-25  1458.650024  1495.000000  1444.000000  1488.050049
#
# [143 rows x 4 columns]

# %%
low=stk_data["Low"]

# %%
low
# Out:
# Date
# 2021-07-01    1483.000000
# 2021-07-02    1477.000000
# 2021-07-05    1484.550049
# 2021-07-06    1496.000000
# 2021-07-07    1527.699951
#                  ...
# 2022-01-19    1513.349976
# 2022-01-20    1500.099976
# 2022-01-21    1485.599976
# 2022-01-24    1467.550049
# 2022-01-25    1444.000000
# Name: Low, Length: 143, dtype: float64

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
dataset=stk_data
quan,qual=obj.segreQuanQual(dataset)
# Out:
# The Quantitative Data: ['Open', 'High', 'Low', 'Close']
# The Qualtitative Data []

# %%
des_data=obj.descriptive_Analysis(dataset,quan)

# %%
des_data
# Out:
#                       Open         High          Low        Close
# Null_count               0            0            0            0
# NonNull_count          143          143          143          143
# Total_Count            143          143          143          143
# Mean           1536.233915  1550.337061  1523.032869  1536.692311
# Median              1533.0  1548.699951  1520.400024      1529.25
# Mode                1497.0       1572.0       1445.0  1417.300049
# Std              62.260936    62.911968    60.715342    61.414979
# Min                 1410.0  1429.949951       1404.0  1417.300049
# Q1:25%              1497.0     1507.625  1485.299988  1500.049988
# Q2:50%              1533.0  1548.699951  1520.400024      1529.25
# Q3:75%         1572.974976  1583.674988  1561.474976  1574.150024
# Q4:100%             1705.0       1725.0       1671.0  1688.699951
# IQR              75.974976    76.049988    76.174988    74.100037
# 1.5Rule         113.962463   114.074982   114.262482   111.150055
# Lesser         1383.037537  1393.550018  1371.037506  1388.899933
# Greater        1686.937439  1697.749969  1675.737457  1685.300079

# %%
des_data.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close'], dtype='object')

# %%
print(des_data.columns)
# Out:
# Index(['Open', 'High', 'Low', 'Close'], dtype='object')

# %%
des_data['Low']
# Out:
# Null_count                 0
# NonNull_count            143
# Total_Count              143
# Mean             1523.032869
# Median           1520.400024
# Mode                  1445.0
# Std                60.715342
# Min                   1404.0
# Q1:25%           1485.299988
# Q2:50%           1520.400024
# Q3:75%           1561.474976
# Q4:100%               1671.0
# IQR                76.174988
# 1.5Rule           114.262482
# Lesser           1371.037506
# Greater          1675.737457
# Name: Low, dtype: object

# %%
des_data['High']
# Out:
# Null_count                 0
# NonNull_count            143
# Total_Count              143
# Mean             1550.337061
# Median           1548.699951
# Mode                  1572.0
# Std                62.911968
# Min              1429.949951
# Q1:25%              1507.625
# Q2:50%           1548.699951
# Q3:75%           1583.674988
# Q4:100%               1725.0
# IQR                76.049988
# 1.5Rule           114.074982
# Lesser           1393.550018
# Greater          1697.749969
# Name: High, dtype: object

# %%
import numpy as np

# %%
np.percentile(dataset['Low'],99)
# Out:
# 1669.1960205078126

# %%
np.percentile(dataset['High'],80)
# Out:
# 1597.939990234375

# %%
#!pip install seaborn

# %%
def get_pdf_probability(dataset,startrange,endrange):
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns
    ax = sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
    pyplot.axvline(startrange,color='Red')
    pyplot.axvline(endrange,color='Red')
    # generate a sample
    sample = dataset
    # calculate parameters
    sample_mean =sample.mean()
    sample_std = sample.std()
    print('Mean=%.3f, Standard Deviation=%.3f' % (sample_mean, sample_std))
    # define the distribution
    dist = norm(sample_mean, sample_std)
    
    # sample probabilities for a range of outcomes
    values = [value for value in range(startrange, endrange)]
    probabilities = [dist.pdf(value) for value in values]    
    prob=sum(probabilities)
    print("The area between range({},{}):{}".format(startrange,endrange,sum(probabilities)))
    return prob

# %%
get_pdf_probability(dataset['Low'],219,230)
# Out:
# Mean=1523.033, Standard Deviation=60.715
# The area between range(219,230):4.984048162092704e-101
# 4.984048162092704e-101

# %%
def stdNBgraph(dataset):
        # Coverted to standard Normal Distribution
    import seaborn as sns
    mean=dataset.mean()
    std=dataset.std()

    values=[i for i in dataset]

    z_score=[((j-mean)/std) for j in values]

    sns.distplot(z_score,kde=True)

    sum(z_score)/len(z_score)
    #z_score.std()

# %%
stdNBgraph(dataset['Low'])

# %%
def freqTable(columnName, dataset):
    import pandas as pd
    frq=pd.DataFrame()
    frq["Unique_Values"]=dataset[columnName].value_counts().index
    frq["Frequency"]=dataset[columnName].value_counts().values
    frq["Relative_Fre"]=dataset[columnName].value_counts().values/len(dataset[columnName])*100
    frq["Cumulative"]=frq["Relative_Fre"].cumsum()
    return frq

# %%
freqTable(('Low'), dataset)
# Out:
#      Unique_Values  Frequency  Relative_Fre  Cumulative
# 0      1445.000000          2      1.398601    1.398601
# 1      1483.000000          1      0.699301    2.097902
# 2      1535.599976          1      0.699301    2.797203
# 3      1554.400024          1      0.699301    3.496503
# 4      1541.599976          1      0.699301    4.195804
# ..             ...        ...           ...         ...
# 137    1574.500000          1      0.699301   97.202797
# 138    1562.199951          1      0.699301   97.902098
# 139    1551.599976          1      0.699301   98.601399
# 140    1545.250000          1      0.699301   99.300699
# 141    1444.000000          1      0.699301  100.000000
#
# [142 rows x 4 columns]

# %%
freqTable(('High'), dataset)
# Out:
#      Unique_Values  Frequency  Relative_Fre  Cumulative
# 0      1572.000000          3      2.097902    2.097902
# 1      1507.349976          2      1.398601    3.496503
# 2      1507.050049          2      1.398601    4.895105
# 3      1589.000000          2      1.398601    6.293706
# 4      1454.000000          2      1.398601    7.692308
# ..             ...        ...           ...         ...
# 126    1580.949951          1      0.699301   97.202797
# 127    1592.000000          1      0.699301   97.902098
# 128    1583.349976          1      0.699301   98.601399
# 129    1570.000000          1      0.699301   99.300699
# 130    1495.000000          1      0.699301  100.000000
#
# [131 rows x 4 columns]

# %%
fh=freqTable(("High"),dataset)

# %%
fh.sort_values(by="Frequency",ascending=False)
# Out:
#      Unique_Values  Frequency  Relative_Fre  Cumulative
# 0      1572.000000          3      2.097902    2.097902
# 6      1502.000000          2      1.398601   10.489510
# 1      1507.349976          2      1.398601    3.496503
# 10     1598.000000          2      1.398601   16.083916
# 9      1690.000000          2      1.398601   14.685315
# ..             ...        ...           ...         ...
# 45     1556.000000          1      0.699301   40.559441
# 44     1550.900024          1      0.699301   39.860140
# 43     1539.750000          1      0.699301   39.160839
# 42     1528.500000          1      0.699301   38.461538
# 130    1495.000000          1      0.699301  100.000000
#
# [131 rows x 4 columns]

# %%
fhs=fh[fh["Frequency"]==2]["Unique_Values"].sort_values(ascending=False)

# %%
fhs
# Out:
# 9     1690.000000
# 5     1622.000000
# 10    1598.000000
# 3     1589.000000
# 8     1564.500000
# 7     1516.000000
# 1     1507.349976
# 2     1507.050049
# 6     1502.000000
# 4     1454.000000
# Name: Unique_Values, dtype: float64
