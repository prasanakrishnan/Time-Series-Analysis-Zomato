# %%
import pandas as pd
#!pip install yfinance
#!pip install nsepy

# %%
from Descriptive import Descriptive

# %%
obj=Descriptive()

# %%
import datetime as dt
import yfinance as yf
import pandas as pd

# Define the time period and stock symbol
start = dt.datetime(2021, 6, 1)
end = dt.datetime(2022, 1, 5)
symbol = 'ZOMATO.NS'

# Download stock data
stk_data = yf.download(symbol, start=start, end=end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
stk_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 113 entries, 2021-07-23 to 2022-01-04
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   (Adj Close, ZOMATO.NS)  113 non-null    float64
#  1   (Close, ZOMATO.NS)      113 non-null    float64
#  2   (High, ZOMATO.NS)       113 non-null    float64
#  3   (Low, ZOMATO.NS)        113 non-null    float64
#  4   (Open, ZOMATO.NS)       113 non-null    float64
#  5   (Volume, ZOMATO.NS)     113 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 6.2 KB

# %%
stk_data = stk_data[["Open", "High", "Low", "Close"]]

# %%
stk_data
# Out:
# Price             Open        High         Low       Close
# Ticker       ZOMATO.NS   ZOMATO.NS   ZOMATO.NS   ZOMATO.NS
# Date
# 2021-07-23  116.000000  138.899994  115.000000  126.000000
# 2021-07-26  126.349998  143.750000  125.300003  140.649994
# 2021-07-27  141.699997  147.800003  127.750000  132.899994
# 2021-07-28  131.000000  135.000000  123.550003  131.199997
# 2021-07-29  134.949997  144.000000  132.199997  141.550003
# ...                ...         ...         ...         ...
# 2021-12-29  132.699997  137.699997  131.550003  137.100006
# 2021-12-30  137.050003  137.050003  133.300003  133.949997
# 2021-12-31  133.850006  138.399994  133.399994  137.399994
# 2022-01-03  139.699997  142.449997  138.300003  141.350006
# 2022-01-04  141.350006  141.550003  137.600006  138.350006
#
# [113 rows x 4 columns]

# %%
# Adjust to your column names
new_headers = ['Open','High','Low','Close'] 
stk_data.columns = new_headers

# %%
stk_data
# Out:
#                   Open        High         Low       Close
# Date
# 2021-07-23  116.000000  138.899994  115.000000  126.000000
# 2021-07-26  126.349998  143.750000  125.300003  140.649994
# 2021-07-27  141.699997  147.800003  127.750000  132.899994
# 2021-07-28  131.000000  135.000000  123.550003  131.199997
# 2021-07-29  134.949997  144.000000  132.199997  141.550003
# ...                ...         ...         ...         ...
# 2021-12-29  132.699997  137.699997  131.550003  137.100006
# 2021-12-30  137.050003  137.050003  133.300003  133.949997
# 2021-12-31  133.850006  138.399994  133.399994  137.399994
# 2022-01-03  139.699997  142.449997  138.300003  141.350006
# 2022-01-04  141.350006  141.550003  137.600006  138.350006
#
# [113 rows x 4 columns]

# %%
stk_data.to_csv(' ZOMATO_stock_data.csv', index=True)

# %%
stk_data
# Out:
#                   Open        High         Low       Close
# Date
# 2021-07-23  116.000000  138.899994  115.000000  126.000000
# 2021-07-26  126.349998  143.750000  125.300003  140.649994
# 2021-07-27  141.699997  147.800003  127.750000  132.899994
# 2021-07-28  131.000000  135.000000  123.550003  131.199997
# 2021-07-29  134.949997  144.000000  132.199997  141.550003
# ...                ...         ...         ...         ...
# 2021-12-29  132.699997  137.699997  131.550003  137.100006
# 2021-12-30  137.050003  137.050003  133.300003  133.949997
# 2021-12-31  133.850006  138.399994  133.399994  137.399994
# 2022-01-03  139.699997  142.449997  138.300003  141.350006
# 2022-01-04  141.350006  141.550003  137.600006  138.350006
#
# [113 rows x 4 columns]

# %%
low=stk_data["Low"]

# %%
low
# Out:
# Date
# 2021-07-23    115.000000
# 2021-07-26    125.300003
# 2021-07-27    127.750000
# 2021-07-28    123.550003
# 2021-07-29    132.199997
#                  ...
# 2021-12-29    131.550003
# 2021-12-30    133.300003
# 2021-12-31    133.399994
# 2022-01-03    138.300003
# 2022-01-04    137.600006
# Name: Low, Length: 113, dtype: float64

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
dataset=stk_data
quan,qual=obj.segreQuanQual(dataset)
# Out:
# The Quantitative Data: ['Open', 'High', 'Low', 'Close']
# The Qualtitative Data []

# %%
des_data=obj.descriptive_Analysis(dataset,quan)

# %%
des_data
# Out:
#                      Open        High         Low       Close
# Null_count              0           0           0           0
# NonNull_count         113         113         113         113
# Total_Count           113         113         113         113
# Mean           138.871681  142.042035  135.002213  138.418142
# Median         137.699997       140.0       134.5  137.600006
# Mode                134.5  138.899994       133.0  134.949997
# Std              7.823393    8.079351      7.0278    7.552474
# Min                 116.0  127.150002       115.0      124.25
# Q1:25%              134.5  137.300003       131.5       133.5
# Q2:50%         137.699997       140.0       134.5  137.600006
# Q3:75%         142.199997  144.949997       138.0  141.350006
# Q4:100%        161.149994       169.0      154.25  160.300003
# IQR              7.699997    7.649994         6.5    7.850006
# 1.5Rule         11.549995   11.474991        9.75   11.775009
# Lesser         122.950005  125.825012      121.75  121.724991
# Greater        153.749992  156.424988      147.75  153.125015

# %%
des_data.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close'], dtype='object')

# %%
des_data['Low']
# Out:
# Null_count                0
# NonNull_count           113
# Total_Count             113
# Mean             135.002213
# Median                134.5
# Mode                  133.0
# Std                  7.0278
# Min                   115.0
# Q1:25%                131.5
# Q2:50%                134.5
# Q3:75%                138.0
# Q4:100%              154.25
# IQR                     6.5
# 1.5Rule                9.75
# Lesser               121.75
# Greater              147.75
# Name: Low, dtype: object

# %%
des_data['High']
# Out:
# Null_count                0
# NonNull_count           113
# Total_Count             113
# Mean             142.042035
# Median                140.0
# Mode             138.899994
# Std                8.079351
# Min              127.150002
# Q1:25%           137.300003
# Q2:50%                140.0
# Q3:75%           144.949997
# Q4:100%               169.0
# IQR                7.649994
# 1.5Rule           11.474991
# Lesser           125.825012
# Greater          156.424988
# Name: High, dtype: object

# %%
import numpy as np

# %%
np.percentile(dataset['Low'],99)
# Out:
# 154.0200030517578

# %%
np.percentile(dataset['High'],80)
# Out:
# 146.85000610351562

# %%
#!pip install seaborn

# %%
def get_pdf_probability(dataset,startrange,endrange):
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns
    ax = sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
    pyplot.axvline(startrange,color='Red')
    pyplot.axvline(endrange,color='Red')
    # generate a sample
    sample = dataset
    # calculate parameters
    sample_mean =sample.mean()
    sample_std = sample.std()
    print('Mean=%.3f, Standard Deviation=%.3f' % (sample_mean, sample_std))
    # define the distribution
    dist = norm(sample_mean, sample_std)
    
    # sample probabilities for a range of outcomes
    values = [value for value in range(startrange, endrange)]
    probabilities = [dist.pdf(value) for value in values]    
    prob=sum(probabilities)
    print("The area between range({},{}):{}".format(startrange,endrange,sum(probabilities)))
    return prob

# %%
get_pdf_probability(dataset['Low'],219,230)
# Out:
# Mean=135.002, Standard Deviation=7.028
# The area between range(219,230):6.60034289545754e-33
# 6.60034289545754e-33

# %%
def stdNBgraph(dataset):
        # Coverted to standard Normal Distribution
    import seaborn as sns
    mean=dataset.mean()
    std=dataset.std()

    values=[i for i in dataset]

    z_score=[((j-mean)/std) for j in values]

    sns.distplot(z_score,kde=True)

    sum(z_score)/len(z_score)
    #z_score.std()

# %%
stdNBgraph(dataset['Low'])

# %%
def freqTable(columnName, dataset):
    import pandas as pd
    frq=pd.DataFrame()
    frq["Unique_Values"]=dataset[columnName].value_counts().index
    frq["Frequency"]=dataset[columnName].value_counts().values
    frq["Relative_Fre"]=dataset[columnName].value_counts().values/len(dataset[columnName])*100
    frq["Cumulative"]=frq["Relative_Fre"].cumsum()
    return frq

# %%
freqTable(('Low'), dataset)
# Out:
#     Unique_Values  Frequency  Relative_Fre  Cumulative
# 0      140.000000          3      2.654867    2.654867
# 1      133.000000          3      2.654867    5.309735
# 2      136.149994          2      1.769912    7.079646
# 3      132.100006          2      1.769912    8.849558
# 4      131.550003          2      1.769912   10.619469
# ..            ...        ...           ...         ...
# 87     136.199997          1      0.884956   96.460177
# 88     139.050003          1      0.884956   97.345133
# 89     138.550003          1      0.884956   98.230088
# 90     143.250000          1      0.884956   99.115044
# 91     137.600006          1      0.884956  100.000000
#
# [92 rows x 4 columns]

# %%
freqTable("High",dataset)
# Out:
#     Unique_Values  Frequency  Relative_Fre  Cumulative
# 0      138.899994          3      2.654867    2.654867
# 1      144.000000          3      2.654867    5.309735
# 2      137.399994          2      1.769912    7.079646
# 3      133.600006          2      1.769912    8.849558
# 4      139.199997          2      1.769912   10.619469
# ..            ...        ...           ...         ...
# 92     152.750000          1      0.884956   96.460177
# 93     144.250000          1      0.884956   97.345133
# 94     142.899994          1      0.884956   98.230088
# 95     143.600006          1      0.884956   99.115044
# 96     141.550003          1      0.884956  100.000000
#
# [97 rows x 4 columns]

# %%
fh=freqTable("High",dataset)

# %%
fh.sort_values(by="Frequency",ascending=False)
# Out:
#     Unique_Values  Frequency  Relative_Fre  Cumulative
# 0      138.899994          3      2.654867    2.654867
# 1      144.000000          3      2.654867    5.309735
# 8      146.850006          2      1.769912   17.699115
# 13     135.000000          2      1.769912   26.548673
# 12     140.750000          2      1.769912   24.778761
# ..            ...        ...           ...         ...
# 38     132.850006          1      0.884956   48.672566
# 37     137.699997          1      0.884956   47.787611
# 36     134.000000          1      0.884956   46.902655
# 35     161.300003          1      0.884956   46.017699
# 96     141.550003          1      0.884956  100.000000
#
# [97 rows x 4 columns]

# %%
fhs=fh[fh["Frequency"]==2]["Unique_Values"].sort_values(ascending=False)

# %%
fhs
# Out:
# 8     146.850006
# 10    142.000000
# 11    141.000000
# 12    140.750000
# 6     140.399994
# 9     139.750000
# 5     139.500000
# 4     139.199997
# 7     138.000000
# 2     137.399994
# 13    135.000000
# 3     133.600006
# Name: Unique_Values, dtype: float64
